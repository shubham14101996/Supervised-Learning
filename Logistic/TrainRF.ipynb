# %%
import pandas as pd

# %%
df = pd.read_csv('trainRF.csv')

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %% [markdown]
# # Train Test Model

# %%
from sklearn.model_selection import train_test_split
df_train , df_test = train_test_split(df, test_size = .2)

# %%
df_train_x = df_train.iloc[:,0:-1]
df_train_y = df_train.iloc[:,-1]

df_test_x = df_test.iloc[:,0:-1]
df_test_y = df_test.iloc[:,-1]

# %% [markdown]
# # Model 1

# %%
from sklearn.tree import DecisionTreeClassifier
dt_Normal = DecisionTreeClassifier()

# %%
dt_Normal.fit(df_train_x, df_train_y)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt_Normal = dt_Normal.predict(df_test_x)

# %%
from sklearn.metrics import confusion_matrix

# %%
tab_dt_Normal = confusion_matrix(pred_dt_Normal, df_test_y)

# %%
tab_dt_Normal
# Out:
# array([[94, 11,  0,  0],
#        [ 8, 76,  9,  0],
#        [ 0, 14, 81, 20],
#        [ 0,  1, 16, 70]], dtype=int64)

# %%
tab_dt_Normal[1]
# Out:
# array([ 8, 76,  9,  0], dtype=int64)

# %%
Acc_dt_Normal = tab_dt_Normal.diagonal().sum() * 100/ tab_dt_Normal.sum()
print('Accuracy of Normal Decision tree with all default values i.e criterion="gini index"',Acc_dt_Normal,'%')
# Out:
# Accuracy of Normal Decision tree with all default values i.e criterion="gini index" 80.25 %

# %%
Error_class_zero = (tab_dt_Normal[0][0]/tab_dt_Normal[0].sum()*100).round(2)
print('Error for class Zero of First Confusion Matrix',Error_class_zero*100,'%')

Error_class_one = (tab_dt_Normal[1][1]/tab_dt_Normal[1].sum()*100).round(2)
print('Error for class One of First Confusion Matrix',Error_class_one,'%')

Error_class_two = (tab_dt_Normal[2][2]/tab_dt_Normal[2].sum()*100).round(2)
print('Error for class Two of First Confusion Matrix',Error_class_two*100,'%')

Error_class_three = (tab_dt_Normal[1][1]/tab_dt_Normal[1].sum()*100).round(2)
print('Error for class Three of First Confusion Matrix',Error_class_three,'%')
# Out:
# Error for class Zero of First Confusion Matrix 8952.0 %
# Error for class One of First Confusion Matrix 81.72 %
# Error for class Two of First Confusion Matrix 7043.000000000001 %
# Error for class Three of First Confusion Matrix 81.72 %

# %%
dt_Normal.feature_importances_
# Out:
# array([0.12586782, 0.        , 0.00561947, 0.00088896, 0.00605204,
#        0.00138899, 0.01943257, 0.00917268, 0.00329222, 0.00445589,
#        0.0105658 , 0.09102809, 0.09274091, 0.61191113, 0.00259742,
#        0.00734182, 0.00326291, 0.00238113, 0.        , 0.00200015])

# %%
dt_Normal.feature_importances_.sum()
# Out:
# 1.0000000000000002

# %%
feature_importance_df_Normal = pd.DataFrame({'Importance':dt_Normal.feature_importances_*100, 'variables':df_train_x.columns})

# %%
feature_importance_df_Normal.sort_values('Importance', ascending= False).reset_index()
# Out:
#     index  Importance      variables
# 0      13   61.191113            ram
# 1       0   12.586782  battery_power
# 2      12    9.274091       px_width
# 3      11    9.102809      px_height
# 4       6    1.943257     int_memory
# 5      10    1.056580             pc
# 6       7    0.917268          m_dep
# 7      15    0.734182           sc_w
# 8       4    0.605204             fc
# 9       2    0.561947    clock_speed
# 10      9    0.445589        n_cores
# 11      8    0.329222      mobile_wt
# 12     16    0.326291      talk_time
# 13     14    0.259742           sc_h
# 14     17    0.238113        three_g
# 15     19    0.200015           wifi
# 16      5    0.138899         four_g
# 17      3    0.088896       dual_sim
# 18      1    0.000000           blue
# 19     18    0.000000   touch_screen

# %% [markdown]
# # Model 2 using Class Weight = 'Balanced'

# %%
dt_balanced = DecisionTreeClassifier(max_depth = 6, min_samples_split = 150, class_weight='balanced')
print(dt_balanced.fit(df_train_x, df_train_y))
dt_balanced_pred = dt_balanced.predict(df_test_x)

from sklearn.metrics import confusion_matrix
tab_dt_balanced = confusion_matrix(dt_balanced_pred, df_test_y)
print(tab_dt_balanced)
print(dt_balanced.feature_importances_)
feature_importance_balanced = pd.DataFrame({'Importance':dt_balanced.feature_importances_*100, 'variables':df_train_x.columns})
feature_importance_balanced.sort_values('Importance', ascending=False)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=6,
#                        min_samples_split=150)
# [[95 12  0  0]
#  [ 7 59  6  0]
#  [ 0 31 80 14]
#  [ 0  0 20 76]]
# [0.14876828 0.         0.         0.         0.         0.
#  0.00235155 0.         0.         0.         0.         0.0406801
#  0.         0.80820007 0.         0.         0.         0.
#  0.         0.        ]
#     Importance      variables
# 13   80.820007            ram
# 0    14.876828  battery_power
# 11    4.068010      px_height
# 6     0.235155     int_memory
# 18    0.000000   touch_screen
# 17    0.000000        three_g
# 16    0.000000      talk_time
# 15    0.000000           sc_w
# 14    0.000000           sc_h
# 12    0.000000       px_width
# 10    0.000000             pc
# 1     0.000000           blue
# 9     0.000000        n_cores
# 8     0.000000      mobile_wt
# 7     0.000000          m_dep
# 5     0.000000         four_g
# 4     0.000000             fc
# ...

# %% [markdown]
# # Model 3 Using Entropy as Criteria

# %%
dt_balanced = DecisionTreeClassifier(criterion="entropy",max_depth = 6, min_samples_split = 150, class_weight='balanced')
print(dt_balanced.fit(df_train_x, df_train_y))
dt_balanced_pred = dt_balanced.predict(df_test_x)
print('---------------')
print('-----CONFUSION MATRIX------')
from sklearn.metrics import confusion_matrix
tab_dt_balanced = confusion_matrix(dt_balanced_pred, df_test_y)
print(tab_dt_balanced)
print('-----------------')
print('-----IMPORTANT FEATURES-------')
dt_balanced.feature_importances_
feature_importance_balanced = pd.DataFrame({'Importance':dt_balanced.feature_importances_*100, 'variables':df_train_x.columns})
feature_importance_balanced.sort_values('Importance', ascending=False)
# Out:
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=6, min_samples_split=150)
# ---------------
# -----CONFUSION MATRIX------
# [[95 12  0  0]
#  [ 7 64  5  0]
#  [ 0 26 92 28]
#  [ 0  0  9 62]]
# -----------------
# -----IMPORTANT FEATURES-------
#     Importance      variables
# 13   82.207582            ram
# 0    11.746028  battery_power
# 11    4.188393      px_height
# 12    1.606198       px_width
# 8     0.251799      mobile_wt
# 18    0.000000   touch_screen
# 17    0.000000        three_g
# 16    0.000000      talk_time
# 15    0.000000           sc_w
# 14    0.000000           sc_h
# 10    0.000000             pc
# 1     0.000000           blue
# 9     0.000000        n_cores
# 7     0.000000          m_dep
# 6     0.000000     int_memory
# 5     0.000000         four_g
# 4     0.000000             fc
# 3     0.000000       dual_sim
# 2     0.000000    clock_speed
# 19    0.000000           wifi

# %%
# Out:
# 4

# %% [markdown]
# # Model 4 Min Sample Split = 200

# %%
dt_balanced = DecisionTreeClassifier(criterion="entropy",max_depth = 6, min_samples_split = 200, class_weight='balanced')
print(dt_balanced.fit(df_train_x, df_train_y))
dt_balanced_pred = dt_balanced.predict(df_test_x)
print('---------------')
print('-----CONFUSION MATRIX------')

from sklearn.metrics import confusion_matrix
tab_dt_balanced = confusion_matrix(dt_balanced_pred, df_test_y)
print(tab_dt_balanced)
print('-----------------')

print('-----IMPORTANT FEATURES-------')

dt_balanced.feature_importances_
feature_importance_balanced = pd.DataFrame({'Importance':dt_balanced.feature_importances_*100, 'variables':df_train_x.columns})
feature_importance_balanced.sort_values('Importance', ascending=False)
# Out:
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=6, min_samples_split=200)
# ---------------
# -----CONFUSION MATRIX------
# [[76 10  0  0]
#  [26 66  5  0]
#  [ 0 26 92 28]
#  [ 0  0  9 62]]
# -----------------
# -----IMPORTANT FEATURES-------
#     Importance      variables
# 13   87.160534            ram
# 0     9.352752  battery_power
# 11    1.755488      px_height
# 12    1.731226       px_width
# 1     0.000000           blue
# 18    0.000000   touch_screen
# 17    0.000000        three_g
# 16    0.000000      talk_time
# 15    0.000000           sc_w
# 14    0.000000           sc_h
# 10    0.000000             pc
# 9     0.000000        n_cores
# 8     0.000000      mobile_wt
# 7     0.000000          m_dep
# 6     0.000000     int_memory
# 5     0.000000         four_g
# 4     0.000000             fc
# 3     0.000000       dual_sim
# 2     0.000000    clock_speed
# 19    0.000000           wifi

# %%
# Model 5

# %%
def Accuracy():
    a = len(tab_dt_balanced)
    for n in range(a):
            Error_class_zero = (tab_dt_Normal[n][n]/tab_dt_Normal[n].sum()*100).round(2)
            print('Error for class {} of First Confusion Matrix {}'.format(n, Error_class_zero,'%'))

# %%
Accuracy()
# Out:
# Error for class 0 of First Confusion Matrix 89.52
# Error for class 1 of First Confusion Matrix 81.72
# Error for class 2 of First Confusion Matrix 70.43
# Error for class 3 of First Confusion Matrix 80.46
